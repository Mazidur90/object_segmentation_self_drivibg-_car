# %%
from ultralytics import YOLO
model= YOLO('yolov8n-seg.pt')
results = model.predict(source=1, stream=True, show=True)  # results list
for r in results:
    print(r.keypoints)  # print the Keypoints object containing the detected keypoints
# Out:
# ...
# 100%|██████████| 6.73M/6.73M [00:01<00:00, 3.67MB/s]
# 1/1: 1... Success ✅ (inf frames of shape 640x480 at 30.00 FPS)
#
# None
# 0: 480x640 1 person, 155.3ms
# None
# 0: 480x640 1 person, 112.2ms
# None
# 0: 480x640 1 person, 109.1ms
# None
# 0: 480x640 1 person, 111.6ms
# None
# 0: 480x640 1 person, 122.0ms
# None
# 0: 480x640 1 person, 126.7ms
# None
# 0: 480x640 1 person, 128.7ms
# None
# 0: 480x640 1 person, 132.2ms
# None
# 0: 480x640 1 person, 123.0ms
# None
# 0: 480x640 1 person, 120.0ms
# None
# 0: 480x640 1 person, 109.9ms
# None
# 0: 480x640 1 person, 118.1ms
# None
# 0: 480x640 1 person, 121.8ms
# None
# 0: 480x640 1 person, 98.5ms
# None
# 0: 480x640 1 person, 108.8ms
# None
# 0: 480x640 1 person, 106.8ms
# None
# 0: 480x640 1 person, 108.1ms
# None
# 0: 480x640 1 person, 99.2ms
# None
# 0: 480x640 1 person, 679.3ms
# None
# 0: 480x640 1 person, 916.6ms
# None
# 0: 480x640 1 person, 1017.6ms
# None
# 0: 480x640 1 person, 2496.2ms
# None
# 0: 480x640 1 person, 2061.9ms
# ...
